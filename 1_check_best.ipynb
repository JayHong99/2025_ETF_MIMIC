# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import shutil

# %%
batch_size=512
projection_dim=128


total_results = []

for task in ['mortality_90days', 'readmission_15days'] :
# for task in ['readmission_15days'] :
    for seed in range(2026, 2029) : 
        for modality in ['tabular', 'lab', 'note'] :
            if modality == 'note' : 
                suffixes = ['_FINETUNE', '_FREEZE']
            else : 
                suffixes = ['']
            for suffix in suffixes :
                result_dir = Path(f'Results/Linear_{modality}/Seed_{seed}/{task}_proj_{projection_dim}_batch_{batch_size}{suffix}')
                exp_dir = result_dir
                output_dir = exp_dir / 'outputs'
                model_dir = exp_dir / 'models'
                model_paths = list(model_dir.glob('linear_epoch*.pth'))
                # {epoch : model_path}
                model_paths = {int(p.stem.split('_')[1].replace('epoch', '')) : p for p in model_paths}
                
                best_output_save_path = output_dir / 'best_epoch.pkl'
                best_score_save_path = output_dir / 'best_epoch_scores.pkl'
                best_score =0
                save = True 
                for epoch in range(1, 101) : 
                    epoch_output_path = output_dir / f'epoch{epoch:03d}_scores.pkl'
                    if not epoch_output_path.exists() :
                        continue
                    epoch_output = pickle.load(open(epoch_output_path, 'rb'))
                    
                    valid_output = epoch_output['valid']
                    valid_score = valid_output['auroc'] + valid_output['auprc']
                    if valid_score > best_score : 
                        best_score = valid_score
                        best_epoch = epoch
                        best_epoch_output = epoch_output
                        # print(f"Best Epoch : {best_epoch} with Valid Score : {best_score:.4f} | AUROC : {valid_output['auroc']:.4f}, AUPRC : {valid_output['auprc']:.4f} | TEST AUROC : {epoch_output['test']['auroc']:.4f}, AUPRC : {epoch_output['test']['auprc']:.4f}")
                if save : 
                    shutil.copy(output_dir / f'epoch{best_epoch:03d}.pkl', best_output_save_path)
                    shutil.copy(output_dir / f'epoch{best_epoch:03d}_scores.pkl', best_score_save_path)
                    model_path = model_paths[best_epoch]
                    best_model_save_path = model_dir / 'best_model.pth'
                    shutil.copy(model_path, best_model_save_path)
                    print(f"Copied best epoch output to {best_output_save_path} & {best_score_save_path}")
                total_results.append({
                    'seed' : seed,
                    'task' : task,
                    'modality' : modality+suffix,
                    'best_epoch' : best_epoch,
                    'valid_auroc' : best_epoch_output['valid']['auroc'],
                    'valid_auprc' : best_epoch_output['valid']['auprc'],
                    'test_auroc' : best_epoch_output['test']['auroc'],
                    'test_auprc' : best_epoch_output['test']['auprc'],
                })
total_results_df = pd.DataFrame(total_results)
total_results_df
# Out:
# Copied best epoch output to Results/Linear_tabular/Seed_2026/mortality_90days_proj_128_batch_512/outputs/best_epoch.pkl & Results/Linear_tabular/Seed_2026/mortality_90days_proj_128_batch_512/outputs/best_epoch_scores.pkl
# Copied best epoch output to Results/Linear_lab/Seed_2026/mortality_90days_proj_128_batch_512/outputs/best_epoch.pkl & Results/Linear_lab/Seed_2026/mortality_90days_proj_128_batch_512/outputs/best_epoch_scores.pkl
# Copied best epoch output to Results/Linear_note/Seed_2026/mortality_90days_proj_128_batch_512_FINETUNE/outputs/best_epoch.pkl & Results/Linear_note/Seed_2026/mortality_90days_proj_128_batch_512_FINETUNE/outputs/best_epoch_scores.pkl
# Copied best epoch output to Results/Linear_note/Seed_2026/mortality_90days_proj_128_batch_512_FREEZE/outputs/best_epoch.pkl & Results/Linear_note/Seed_2026/mortality_90days_proj_128_batch_512_FREEZE/outputs/best_epoch_scores.pkl
# Copied best epoch output to Results/Linear_tabular/Seed_2027/mortality_90days_proj_128_batch_512/outputs/best_epoch.pkl & Results/Linear_tabular/Seed_2027/mortality_90days_proj_128_batch_512/outputs/best_epoch_scores.pkl
# Copied best epoch output to Results/Linear_lab/Seed_2027/mortality_90days_proj_128_batch_512/outputs/best_epoch.pkl & Results/Linear_lab/Seed_2027/mortality_90days_proj_128_batch_512/outputs/best_epoch_scores.pkl
# Copied best epoch output to Results/Linear_note/Seed_2027/mortality_90days_proj_128_batch_512_FINETUNE/outputs/best_epoch.pkl & Results/Linear_note/Seed_2027/mortality_90days_proj_128_batch_512_FINETUNE/outputs/best_epoch_scores.pkl
# Copied best epoch output to Results/Linear_note/Seed_2027/mortality_90days_proj_128_batch_512_FREEZE/outputs/best_epoch.pkl & Results/Linear_note/Seed_2027/mortality_90days_proj_128_batch_512_FREEZE/outputs/best_epoch_scores.pkl
# Copied best epoch output to Results/Linear_tabular/Seed_2028/mortality_90days_proj_128_batch_512/outputs/best_epoch.pkl & Results/Linear_tabular/Seed_2028/mortality_90days_proj_128_batch_512/outputs/best_epoch_scores.pkl
# Copied best epoch output to Results/Linear_lab/Seed_2028/mortality_90days_proj_128_batch_512/outputs/best_epoch.pkl & Results/Linear_lab/Seed_2028/mortality_90days_proj_128_batch_512/outputs/best_epoch_scores.pkl
# Copied best epoch output to Results/Linear_note/Seed_2028/mortality_90days_proj_128_batch_512_FINETUNE/outputs/best_epoch.pkl & Results/Linear_note/Seed_2028/mortality_90days_proj_128_batch_512_FINETUNE/outputs/best_epoch_scores.pkl
# Copied best epoch output to Results/Linear_note/Seed_2028/mortality_90days_proj_128_batch_512_FREEZE/outputs/best_epoch.pkl & Results/Linear_note/Seed_2028/mortality_90days_proj_128_batch_512_FREEZE/outputs/best_epoch_scores.pkl
# Copied best epoch output to Results/Linear_tabular/Seed_2026/readmission_15days_proj_128_batch_512/outputs/best_epoch.pkl & Results/Linear_tabular/Seed_2026/readmission_15days_proj_128_batch_512/outputs/best_epoch_scores.pkl
# Copied best epoch output to Results/Linear_lab/Seed_2026/readmission_15days_proj_128_batch_512/outputs/best_epoch.pkl & Results/Linear_lab/Seed_2026/readmission_15days_proj_128_batch_512/outputs/best_epoch_scores.pkl
# Copied best epoch output to Results/Linear_note/Seed_2026/readmission_15days_proj_128_batch_512_FINETUNE/outputs/best_epoch.pkl & Results/Linear_note/Seed_2026/readmission_15days_proj_128_batch_512_FINETUNE/outputs/best_epoch_scores.pkl
# Copied best epoch output to Results/Linear_note/Seed_2026/readmission_15days_proj_128_batch_512_FREEZE/outputs/best_epoch.pkl & Results/Linear_note/Seed_2026/readmission_15days_proj_128_batch_512_FREEZE/outputs/best_epoch_scores.pkl
# Copied best epoch output to Results/Linear_tabular/Seed_2027/readmission_15days_proj_128_batch_512/outputs/best_epoch.pkl & Results/Linear_tabular/Seed_2027/readmission_15days_proj_128_batch_512/outputs/best_epoch_scores.pkl
# Copied best epoch output to Results/Linear_lab/Seed_2027/readmission_15days_proj_128_batch_512/outputs/best_epoch.pkl & Results/Linear_lab/Seed_2027/readmission_15days_proj_128_batch_512/outputs/best_epoch_scores.pkl
# Copied best epoch output to Results/Linear_note/Seed_2027/readmission_15days_proj_128_batch_512_FINETUNE/outputs/best_epoch.pkl & Results/Linear_note/Seed_2027/readmission_15days_proj_128_batch_512_FINETUNE/outputs/best_epoch_scores.pkl
# Copied best epoch output to Results/Linear_note/Seed_2027/readmission_15days_proj_128_batch_512_FREEZE/outputs/best_epoch.pkl & Results/Linear_note/Seed_2027/readmission_15days_proj_128_batch_512_FREEZE/outputs/best_epoch_scores.pkl
# Copied best epoch output to Results/Linear_tabular/Seed_2028/readmission_15days_proj_128_batch_512/outputs/best_epoch.pkl & Results/Linear_tabular/Seed_2028/readmission_15days_proj_128_batch_512/outputs/best_epoch_scores.pkl
# Copied best epoch output to Results/Linear_lab/Seed_2028/readmission_15days_proj_128_batch_512/outputs/best_epoch.pkl & Results/Linear_lab/Seed_2028/readmission_15days_proj_128_batch_512/outputs/best_epoch_scores.pkl
# Copied best epoch output to Results/Linear_note/Seed_2028/readmission_15days_proj_128_batch_512_FINETUNE/outputs/best_epoch.pkl & Results/Linear_note/Seed_2028/readmission_15days_proj_128_batch_512_FINETUNE/outputs/best_epoch_scores.pkl
# Copied best epoch output to Results/Linear_note/Seed_2028/readmission_15days_proj_128_batch_512_FREEZE/outputs/best_epoch.pkl & Results/Linear_note/Seed_2028/readmission_15days_proj_128_batch_512_FREEZE/outputs/best_epoch_scores.pkl
#     seed                task       modality  best_epoch  valid_auroc  \
# 0   2026    mortality_90days        tabular          77     0.819079
# 1   2026    mortality_90days            lab          31     0.754396
# 2   2026    mortality_90days  note_FINETUNE           3     0.817043
# 3   2026    mortality_90days    note_FREEZE          99     0.714525
# 4   2027    mortality_90days        tabular          87     0.817039
# 5   2027    mortality_90days            lab          40     0.745361
# 6   2027    mortality_90days  note_FINETUNE           3     0.820925
# 7   2027    mortality_90days    note_FREEZE          99     0.687887
# 8   2028    mortality_90days        tabular          60     0.828941
# 9   2028    mortality_90days            lab          32     0.749146
# 10  2028    mortality_90days  note_FINETUNE           3     0.824293
# 11  2028    mortality_90days    note_FREEZE          98     0.707463
# 12  2026  readmission_15days        tabular          77     0.670377
# 13  2026  readmission_15days            lab          28     0.603273
# 14  2026  readmission_15days  note_FINETUNE           3     0.621498
# 15  2026  readmission_15days    note_FREEZE          98     0.562415
# 16  2027  readmission_15days        tabular          96     0.686884
# 17  2027  readmission_15days            lab          51     0.607967
# 18  2027  readmission_15days  note_FINETUNE           3     0.636272
# 19  2027  readmission_15days    note_FREEZE          88     0.572389
# 20  2028  readmission_15days        tabular          71     0.674248
# 21  2028  readmission_15days            lab          38     0.599057
# 22  2028  readmission_15days  note_FINETUNE           2     0.624716
# 23  2028  readmission_15days    note_FREEZE         100     0.560233
#
#     valid_auprc  test_auroc  test_auprc
# 0      0.421106    0.820207    0.420561
# 1      0.315571    0.749036    0.307039
# 2      0.484890    0.821119    0.475583
# 3      0.265017    0.696474    0.268350
# 4      0.413502    0.817422    0.420754
# 5      0.297783    0.748570    0.298868
# 6      0.487611    0.822796    0.481710
# 7      0.263925    0.711240    0.269011
# 8      0.437157    0.815528    0.420176
# 9      0.309385    0.747210    0.301525
# 10     0.493744    0.821927    0.474583
# 11     0.279022    0.689326    0.260362
# 12     0.425669    0.674797    0.430504
# 13     0.321471    0.596807    0.316149
# 14     0.343241    0.630627    0.343650
# 15     0.274931    0.558063    0.267503
# 16     0.445703    0.671602    0.428106
# 17     0.327779    0.598046    0.319547
# 18     0.351810    0.627519    0.347773
# 19     0.272623    0.556487    0.275546
# 20     0.431436    0.678662    0.437824
# 21     0.323317    0.604231    0.325379
# 22     0.344664    0.639095    0.352325
# 23     0.271263    0.563438    0.275030
