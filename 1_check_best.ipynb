# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import shutil

# %%
# batch_size=512
# projection_dim=128


# total_results = []

# for task in ['mortality_90days', 'readmission_15days'] :
#     for seed in range(2026, 2029) : 
#         for modality in ['tabular', 'lab', 'note'] :
#             result_dir = Path(f'Results/Linear_{modality}/Seed_{seed}/{task}_proj_{projection_dim}_batch_{batch_size}')
#             exp_dir = result_dir
#             output_dir = exp_dir / 'outputs'
#             model_dir = exp_dir / 'models'
#             model_paths = list(model_dir.glob('linear_epoch*.pth'))
#             # {epoch : model_path}
#             model_paths = {int(p.stem.split('_')[1].replace('epoch', '')) : p for p in model_paths}
            
#             best_output_save_path = output_dir / 'best_epoch.pkl'
#             best_score_save_path = output_dir / 'best_epoch_scores.pkl'
#             best_score =0
#             save = True 
#             for epoch in range(1, 101) : 
#                 epoch_output_path = output_dir / f'epoch{epoch:03d}_scores.pkl'
#                 if not epoch_output_path.exists() :
#                     continue
#                 epoch_output = pickle.load(open(epoch_output_path, 'rb'))
                
#                 valid_output = epoch_output['valid']
#                 valid_score = valid_output['auroc'] + valid_output['auprc']
#                 if valid_score > best_score : 
#                     best_score = valid_score
#                     best_epoch = epoch
#                     best_epoch_output = epoch_output
#                     # print(f"Best Epoch : {best_epoch} with Valid Score : {best_score:.4f} | AUROC : {valid_output['auroc']:.4f}, AUPRC : {valid_output['auprc']:.4f} | TEST AUROC : {epoch_output['test']['auroc']:.4f}, AUPRC : {epoch_output['test']['auprc']:.4f}")
#             if save : 
#                 shutil.copy(output_dir / f'epoch{best_epoch:03d}.pkl', best_output_save_path)
#                 shutil.copy(output_dir / f'epoch{best_epoch:03d}_scores.pkl', best_score_save_path)
#                 model_path = model_paths[best_epoch]
#                 best_model_save_path = model_dir / 'best_model.pth'
#                 shutil.copy(model_path, best_model_save_path)
#                 print(f"Copied best epoch output to {best_output_save_path} & {best_score_save_path}")
#             total_results.append({
#                 'seed' : seed,
#                 'task' : task,
#                 'modality' : modality,
#                 'best_epoch' : best_epoch,
#                 'valid_auroc' : best_epoch_output['valid']['auroc'],
#                 'valid_auprc' : best_epoch_output['valid']['auprc'],
#                 'test_auroc' : best_epoch_output['test']['auroc'],
#                 'test_auprc' : best_epoch_output['test']['auprc'],
#             })
# total_results_df = pd.DataFrame(total_results)
# total_results_df

# %%
batch_size=512
projection_dim=128


total_results = []

for task in ['mortality_90days', 'readmission_15days'] :
    for fusion_method in ['Sum', 'WeightedFusion', 'AttnMaskedFusion'] : 
        for seed in range(2026, 2029) : 
            # Results/Linear_MultiModal/Fusion_AttnMaskedFusion/Seed_2026/mortality_90days_proj_128_batch_512/outputs
            result_dir = Path(f'Results/Linear_MultiModal/Fusion_{fusion_method}/Seed_{seed}/{task}_proj_{projection_dim}_batch_{batch_size}')
            exp_dir = result_dir
            output_dir = exp_dir / 'outputs'
            model_dir = exp_dir / 'models'
            
            best_output_save_path = output_dir / 'best_epoch.pkl'
            best_score_save_path = output_dir / 'best_epoch_scores.pkl'
            
            score_paths = list(output_dir.glob('epoch*_scores.pkl'))
            if len(score_paths) == 0 :
                print(f"No output paths for {result_dir}, skipping...")
                continue
            score_paths = sorted(score_paths, key=lambda x: int(x.stem.split('_')[0].replace('epoch', '')))
            # last epoch is the best
            best_epoch_path = score_paths[-1]
            best_epoch = int(best_epoch_path.stem.split('_')[0].replace('epoch', ''))
            best_epoch_score = pickle.load(open(best_epoch_path, 'rb'))
            
            model_paths = list(model_dir.glob('linear_epoch*.pth'))
            # {epoch : model_path}
            model_paths = {int(p.stem.split('_')[1].replace('epoch', '')) : p for p in model_paths}
            model_path = model_paths[best_epoch]
            
            shutil.copy(output_dir / f'epoch{best_epoch:03d}.pkl', best_output_save_path)
            shutil.copy(output_dir / f'epoch{best_epoch:03d}_scores.pkl', best_score_save_path)
            model_path = model_paths[best_epoch]
            best_model_save_path = model_dir / 'best_model.pth'
            shutil.copy(model_path, best_model_save_path)
            print(f"Copied Best Epoch Output {best_epoch_path} \n\t\t\t-> {best_output_save_path}")
            total_results.append({
                'seed' : seed,
                'task' : task,
                'fusion' : fusion_method,
                'best_epoch' : best_epoch,
                'valid_auroc' : best_epoch_score['valid']['auroc'],
                'valid_auprc' : best_epoch_score['valid']['auprc'],
                'test_auroc' : best_epoch_score['test']['auroc'],
                'test_auprc' : best_epoch_score['test']['auprc'],
            })
total_results_df = pd.DataFrame(total_results)
total_results_df
# Out:
# Copied Best Epoch Output Results/Linear_MultiModal/Fusion_Sum/Seed_2026/mortality_90days_proj_128_batch_512/outputs/epoch066_scores.pkl
# 			-> Results/Linear_MultiModal/Fusion_Sum/Seed_2026/mortality_90days_proj_128_batch_512/outputs/best_epoch.pkl
# Copied Best Epoch Output Results/Linear_MultiModal/Fusion_Sum/Seed_2027/mortality_90days_proj_128_batch_512/outputs/epoch032_scores.pkl
# 			-> Results/Linear_MultiModal/Fusion_Sum/Seed_2027/mortality_90days_proj_128_batch_512/outputs/best_epoch.pkl
# Copied Best Epoch Output Results/Linear_MultiModal/Fusion_Sum/Seed_2028/mortality_90days_proj_128_batch_512/outputs/epoch069_scores.pkl
# 			-> Results/Linear_MultiModal/Fusion_Sum/Seed_2028/mortality_90days_proj_128_batch_512/outputs/best_epoch.pkl
# Copied Best Epoch Output Results/Linear_MultiModal/Fusion_WeightedFusion/Seed_2026/mortality_90days_proj_128_batch_512/outputs/epoch022_scores.pkl
# 			-> Results/Linear_MultiModal/Fusion_WeightedFusion/Seed_2026/mortality_90days_proj_128_batch_512/outputs/best_epoch.pkl
# Copied Best Epoch Output Results/Linear_MultiModal/Fusion_WeightedFusion/Seed_2027/mortality_90days_proj_128_batch_512/outputs/epoch078_scores.pkl
# 			-> Results/Linear_MultiModal/Fusion_WeightedFusion/Seed_2027/mortality_90days_proj_128_batch_512/outputs/best_epoch.pkl
# Copied Best Epoch Output Results/Linear_MultiModal/Fusion_WeightedFusion/Seed_2028/mortality_90days_proj_128_batch_512/outputs/epoch018_scores.pkl
# 			-> Results/Linear_MultiModal/Fusion_WeightedFusion/Seed_2028/mortality_90days_proj_128_batch_512/outputs/best_epoch.pkl
# Copied Best Epoch Output Results/Linear_MultiModal/Fusion_AttnMaskedFusion/Seed_2026/mortality_90days_proj_128_batch_512/outputs/epoch007_scores.pkl
# 			-> Results/Linear_MultiModal/Fusion_AttnMaskedFusion/Seed_2026/mortality_90days_proj_128_batch_512/outputs/best_epoch.pkl
# Copied Best Epoch Output Results/Linear_MultiModal/Fusion_AttnMaskedFusion/Seed_2027/mortality_90days_proj_128_batch_512/outputs/epoch035_scores.pkl
# 			-> Results/Linear_MultiModal/Fusion_AttnMaskedFusion/Seed_2027/mortality_90days_proj_128_batch_512/outputs/best_epoch.pkl
# Copied Best Epoch Output Results/Linear_MultiModal/Fusion_AttnMaskedFusion/Seed_2028/mortality_90days_proj_128_batch_512/outputs/epoch047_scores.pkl
# 			-> Results/Linear_MultiModal/Fusion_AttnMaskedFusion/Seed_2028/mortality_90days_proj_128_batch_512/outputs/best_epoch.pkl
# Copied Best Epoch Output Results/Linear_MultiModal/Fusion_Sum/Seed_2026/readmission_15days_proj_128_batch_512/outputs/epoch005_scores.pkl
# 			-> Results/Linear_MultiModal/Fusion_Sum/Seed_2026/readmission_15days_proj_128_batch_512/outputs/best_epoch.pkl
# Copied Best Epoch Output Results/Linear_MultiModal/Fusion_Sum/Seed_2027/readmission_15days_proj_128_batch_512/outputs/epoch045_scores.pkl
# 			-> Results/Linear_MultiModal/Fusion_Sum/Seed_2027/readmission_15days_proj_128_batch_512/outputs/best_epoch.pkl
# Copied Best Epoch Output Results/Linear_MultiModal/Fusion_Sum/Seed_2028/readmission_15days_proj_128_batch_512/outputs/epoch007_scores.pkl
# 			-> Results/Linear_MultiModal/Fusion_Sum/Seed_2028/readmission_15days_proj_128_batch_512/outputs/best_epoch.pkl
# Copied Best Epoch Output Results/Linear_MultiModal/Fusion_WeightedFusion/Seed_2026/readmission_15days_proj_128_batch_512/outputs/epoch016_scores.pkl
# 			-> Results/Linear_MultiModal/Fusion_WeightedFusion/Seed_2026/readmission_15days_proj_128_batch_512/outputs/best_epoch.pkl
# Copied Best Epoch Output Results/Linear_MultiModal/Fusion_WeightedFusion/Seed_2027/readmission_15days_proj_128_batch_512/outputs/epoch073_scores.pkl
# 			-> Results/Linear_MultiModal/Fusion_WeightedFusion/Seed_2027/readmission_15days_proj_128_batch_512/outputs/best_epoch.pkl
# Copied Best Epoch Output Results/Linear_MultiModal/Fusion_WeightedFusion/Seed_2028/readmission_15days_proj_128_batch_512/outputs/epoch009_scores.pkl
# 			-> Results/Linear_MultiModal/Fusion_WeightedFusion/Seed_2028/readmission_15days_proj_128_batch_512/outputs/best_epoch.pkl
# Copied Best Epoch Output Results/Linear_MultiModal/Fusion_AttnMaskedFusion/Seed_2026/readmission_15days_proj_128_batch_512/outputs/epoch085_scores.pkl
# 			-> Results/Linear_MultiModal/Fusion_AttnMaskedFusion/Seed_2026/readmission_15days_proj_128_batch_512/outputs/best_epoch.pkl
# Copied Best Epoch Output Results/Linear_MultiModal/Fusion_AttnMaskedFusion/Seed_2027/readmission_15days_proj_128_batch_512/outputs/epoch071_scores.pkl
# 			-> Results/Linear_MultiModal/Fusion_AttnMaskedFusion/Seed_2027/readmission_15days_proj_128_batch_512/outputs/best_epoch.pkl
# Copied Best Epoch Output Results/Linear_MultiModal/Fusion_AttnMaskedFusion/Seed_2028/readmission_15days_proj_128_batch_512/outputs/epoch063_scores.pkl
# 			-> Results/Linear_MultiModal/Fusion_AttnMaskedFusion/Seed_2028/readmission_15days_proj_128_batch_512/outputs/best_epoch.pkl
#     seed                task            fusion  best_epoch  valid_auroc  \
# 0   2026    mortality_90days               Sum          66     0.854701
# 1   2027    mortality_90days               Sum          32     0.850201
# 2   2028    mortality_90days               Sum          69     0.856318
# 3   2026    mortality_90days    WeightedFusion          22     0.845025
# 4   2027    mortality_90days    WeightedFusion          78     0.838854
# 5   2028    mortality_90days    WeightedFusion          18     0.854665
# 6   2026    mortality_90days  AttnMaskedFusion           7     0.847795
# 7   2027    mortality_90days  AttnMaskedFusion          35     0.845689
# 8   2028    mortality_90days  AttnMaskedFusion          47     0.856073
# 9   2026  readmission_15days               Sum           5     0.682016
# 10  2027  readmission_15days               Sum          45     0.696916
# 11  2028  readmission_15days               Sum           7     0.684982
# 12  2026  readmission_15days    WeightedFusion          16     0.683179
# 13  2027  readmission_15days    WeightedFusion          73     0.689449
# 14  2028  readmission_15days    WeightedFusion           9     0.683313
# 15  2026  readmission_15days  AttnMaskedFusion          85     0.680263
# 16  2027  readmission_15days  AttnMaskedFusion          71     0.697925
# 17  2028  readmission_15days  AttnMaskedFusion          63     0.686294
#
#     valid_auprc  test_auroc  test_auprc
# 0      0.506358    0.855253    0.501377
# 1      0.497009    0.854879    0.494888
# 2      0.515827    0.848346    0.500702
# 3      0.478957    0.846865    0.477506
# 4      0.475016    0.841844    0.478992
# 5      0.502105    0.841604    0.487727
# 6      0.495151    0.848037    0.481874
# 7      0.486762    0.848141    0.486416
# 8      0.510964    0.843540    0.493405
# 9      0.438639    0.685953    0.439580
# 10     0.458937    0.683015    0.439833
# 11     0.442179    0.692008    0.448278
# 12     0.438445    0.686024    0.438908
# 13     0.452594    0.675961    0.434567
# 14     0.439529    0.689731    0.446185
# 15     0.435312    0.686426    0.442342
# 16     0.458044    0.683892    0.439490
# 17     0.442715    0.691491    0.450343
